# %%
$query = @{ 
    keys1 = '((ctrl.*space)|f12)'

    cmds1 = 'ShowCommandHelp|show.*help'
    cmds2 = 'MenuComplete'
}

function query.keybind { 
    param(
        [string[]]$LiteralKeys,
        [string[]]$KeysRegex
    )
    $lit = Join-Regex -Literal $LiteralKeys
    $regex = Join-Regex -Regex
    <#
    if($LiteralKeys) { 
        $render = $Keys | Join-String -sep '|'  { '({0})' -f @(
            [Regex]::Escape( $_ )
        ) }
    }
    foreach($pattern in $KeysRegex) {
    #>

}

return 
Get-PSReadLineKeyHandler -Bound
| ?{ $_.key -match $query -or $_.chord -match $query } 
| fl


hr

Get-PSReadLineKeyHandler -Bound
| ?{ $_.Function -match $query_cmd } 
| fl
#   $query = 
#$_.key -match 'ctrl.*space' -or $_.chord -match 'ctr.*space' } | fl
# Out:
# hr:
# Line |
#   29 |  hr
#      |  ~~
#      | The term 'hr' is not recognized as a name of a cmdlet, function, script file, or executable program.
# Check the spelling of the name, or if a path was included, verify that the path is correct and try again.
#
# Key         : Enter
# Function    : AcceptLine
# Description : Accept the input or move to the next line if input is missing a closing token.
# Group       : Basic
#
# Key         : Shift+Enter
# Function    : AddLine
# Description : Move the cursor to the next line without attempting to execute the input
# Group       : Basic
#
# Key         : Backspace
# Function    : BackwardDeleteChar
# Description : Delete the character before the cursor
# Group       : Basic
#
# Key         : Ctrl+h
# Function    : BackwardDeleteChar
# Description : Delete the character before the cursor
# Group       : Basic
#
# Key         : Ctrl+Home
# Function    : BackwardDeleteInput
# ...

# %% [markdown]
# determine the default hotkey existed despite
